# %% [markdown]
# # Recent Surveys
#
# This notebook evaluates the most recent surveys and is a benchmark to see how good we can predict consumption using the public available data.

# %%
cd ..
# Out:
# /home/constance/Documents/epfl/MA1/ML/predicting-poverty-through-time/src

# %%
# %autoreload 2
# %load_ext autoreload
# %matplotlib inline
# Out:
# UsageError: Line magic function `%autoreload` not found.

# %%
from lib import estimator_util as eu
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.linear_model import RidgeCV
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import string

# %%
sns.set_theme()

# %%
complete_df, all_cols = eu.get_data("../data/lsms/processed/_all_real.csv", "../data/cnn_features/resnet_trans_all_countries_hyper.csv", "../data/")

# %% [markdown]
# ## Predict r^2 for every country in our dataset.

# %%
def cnn_osm(complete, model_, **params):
    countries = ["NG", "ETH" ,"TZA", "MW"]
    for i, country in enumerate(countries):
        tmp_df = complete.loc[complete.country == country]
        years = tmp_df.groupby(["year"]).groups.keys()
        year = max(years)
        X, y = eu.get_recent_features(tmp_df, [country], all_cols)
        r2, y_hest, _ = eu.run_model(X, y, model_, seed=1, **params)
        fig = eu.plot_predictions(y, y_hest, r2, country, year)
        fig.savefig(f"../figs/{country}_{year}_cnnosm_{model_.__name__}.pdf", dpi=600)

def cnn_osm2(complete, model_, country, **params):
        tmp_df = complete.loc[complete.country == country]
        years = tmp_df.groupby(["year"]).groups.keys()
        year = max(years)
        X, y = eu.get_recent_features(tmp_df, [country], all_cols)
        r2, y_hest, _ = eu.run_model(X, y, model_, seed=1, **params)
        fig = eu.plot_predictions(y, y_hest, r2, country, year)
        fig.savefig(f"../figs/{country}_{year}_cnnosm_{model_.__name__}.pdf", dpi=600)

# %% [markdown]
# ### Prediction using Ridge Regression

# %%
countries = ["NG", "ETH" ,"TZA", "MW"]
for country in countries:
    cnn_osm2(complete_df, Ridge, country, alpha = 1000)

# %% [markdown]
# ### Prediction using XGBoost

# %%
for country in countries:
    cnn_osm2(complete_df, GradientBoostingRegressor)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 2
#       1 for country in countries:
# ----> 2     cnn_osm(complete_df, GradientBoostingRegressor)
#
# Cell In [6], line 8, in cnn_osm(complete, model_, **params)
#       6 year = max(years)
#       7 X, y = eu.get_recent_features(tmp_df, [country], all_cols)
# ----> 8 r2, y_hest, _ = eu.run_model(X, y, model_, seed=1, **params)
#       9 fig = eu.plot_predictions(y, y_hest, r2, country, year)
#      10 fig.savefig(f"../figs/{country}_{year}_cnnosm_{model_.__name__}.pdf", dpi=600)
#
# File ~/Documents/epfl/MA1/ML/predicting-poverty-through-time/src/lib/estimator_util.py:80, in run_model(X, y, model_, seed, **params)
#      78 y_train_fold, y_test_fold = y[train_ind], y[test_ind]
#      79 model = model_(**params)
# ---> 80 model.fit(x_train_fold, y_train_fold)
#      81 y_predict = model.predict(x_test_fold)
#      82 r2.append(pearsonr(y_test_fold, y_predict)[0]**2)
#
# File ~/Lang/python/anaconda3/envs/predicting-poverty-through-time/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:668, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     665     self._resize_state()
#     667 # fit the boosting stages
# --> 668 n_stages = self._fit_stages(
#     669     X,
#     670     y,
#     671     raw_predictions,
#     672     sample_weight,
#     673     self._rng,
#     674     X_val,
#     675     y_val,
#     676     sample_weight_val,
#     677     begin_at_stage,
#     678     monitor,
#     679 )
#     681 # change shape of arrays after fit (early-stopping or additional ests)
#     682 if n_stages != self.estimators_.shape[0]:
#
# File ~/Lang/python/anaconda3/envs/predicting-poverty-through-time/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:745, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     738     old_oob_score = loss_(
#     739         y[~sample_mask],
#     740         raw_predictions[~sample_mask],
#     741         sample_weight[~sample_mask],
#     742     )
#     744 # fit next stage of trees
# --> 745 raw_predictions = self._fit_stage(
#     746     i,
#     747     X,
#     748     y,
#     749     raw_predictions,
#     750     sample_weight,
#     751     sample_mask,
#     752     random_state,
#     753     X_csc,
#     754     X_csr,
#     755 )
#     757 # track deviance (= loss)
#     758 if do_oob:
#
# File ~/Lang/python/anaconda3/envs/predicting-poverty-through-time/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:247, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     244     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     246 X = X_csr if X_csr is not None else X
# --> 247 tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     249 # update tree leaves
#     250 loss.update_terminal_regions(
#     251     tree.tree_,
#     252     X,
#    (...)
#     259     k=k,
#     260 )
#
# File ~/Lang/python/anaconda3/envs/predicting-poverty-through-time/lib/python3.10/site-packages/sklearn/tree/_classes.py:1342, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1313 def fit(self, X, y, sample_weight=None, check_input=True):
#    1314     """Build a decision tree regressor from the training set (X, y).
#    1315
#    1316     Parameters
#    (...)
#    1339         Fitted estimator.
#    1340     """
# -> 1342     super().fit(
#    1343         X,
#    1344         y,
#    1345         sample_weight=sample_weight,
#    1346         check_input=check_input,
#    1347     )
#    1348     return self
#
# File ~/Lang/python/anaconda3/envs/predicting-poverty-through-time/lib/python3.10/site-packages/sklearn/tree/_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
def optimize_params(complete, model_, params, seed):
    kf = KFold(n_splits=10, shuffle=True, random_state=seed)

    countries = ["NG", "ETH" ,"TZA", "MW"]
    best_params = []
    for i, country in enumerate(countries):
        tmp_df = complete.loc[complete.country == country]
        years = tmp_df.groupby(["year"]).groups.keys()
        year = max(years)
        X, y = eu.get_recent_features(tmp_df, [country], all_cols)

        for key in params :
            search = GridSearchCV(model_, param_grid=params, scoring='r2', cv=kf)
            result = search.fit(X,y)
            plt.plot(params[key], result.cv_results_['mean_test_score'], label = country)
            plt.xlabel(key)
            plt.ylabel('r2')
            plt.legend()

        best_params.append(result.best_params_['alpha'])
    return best_params

best_params = optimize_params(complete_df, Ridge(), params={'alpha': np.linspace(500,5000,num=100)}, seed=1)
print(best_params)
# Out:
# [1363.6363636363635, 3454.5454545454545, 1409.090909090909, 1272.7272727272727]

# %%
for i, country in enumerate(countries):
    cnn_osm2(complete_df, Ridge, country, alpha = best_params[i])

# %% [markdown]
# ## Rural vs. Urban

# %%
def rural_urban(complete):    
    types = ["rural", "urban"]
    types_r2 = {}
    rural = []
    ys = []
    y_preds = []
    # get features
    for type in types:    
        r2s = []
        countries = ["NG", "ETH" ,"TZA", "MW"]
        X = None
        y = None
        for i, country in enumerate(countries):
            tmp_df = complete.loc[complete.country == country]
            years = tmp_df.groupby(["year"]).groups.keys()
            year = max(years)
            year_df = tmp_df.loc[tmp_df.year == year]
            year_df = year_df.loc[year_df.rural == type]
            rural += year_df.rural.values.tolist()
            cnn_X = np.array([np.array(x) for x in year_df["features"].values])
            osm_X = year_df[all_cols].values
            tmp_X = np.hstack((cnn_X, osm_X))
            y_ = year_df["cons_pc"].values

            if X is None:
                X = tmp_X
            else:
                X = np.vstack((X, tmp_X))
            
            if y is None:
                y = y_
            else:
                y = np.append(y, y_)

        y = np.log(y)
        ys += y.tolist()
        scaler = StandardScaler().fit(X)
        X = scaler.transform(X)
        r, y_hest, _ = eu.run_ridge(X, y, alpha=1000)
        y_preds += y_hest.tolist()
        r2s.append(r)
        types_r2[type] = r2s

    # for the plot
    plt_df = pd.DataFrame.from_dict({"y": ys, "y_pred": y_preds, "rural": rural})

    x_col = "y"
    y_col = "y_pred"
    hue_col = "rural"

    penguins = plt_df
    g = sns.jointplot(data=penguins, x=x_col, y=y_col, hue=hue_col)
    
    for _, gr in penguins.groupby(hue_col):
        sns.regplot(x=x_col, y=y_col, data=gr, scatter=False, ax=g.ax_joint, truncate=False)
    print(types_r2)
    g.ax_joint.set_xlabel("Observed nominal consumption($/day)")
    g.ax_joint.set_ylabel("Predicted nominal consumption($/day)")
    plt.text(-0.8, 1, fr"$r^2 = {round(types_r2['rural'][0], 2)}$", c="#4c72b0")
    plt.text(-0.8, 0.8, fr"$r^2 = {round(types_r2['urban'][0], 2)}$", c="#dd8452")
    plt.legend([],[], frameon=False)
    g.ax_joint.get_legend().remove()
    g.ax_joint.text(-0.1, 1.1, string.ascii_uppercase[0], size=20, weight='bold', transform=g.ax_joint.transAxes)
    plt.savefig("../figs/rural_urban_pop.pdf", dpi=600, bbox_inches="tight")

# %%
rural_urban(complete_df)
# Out:
# {'rural': [0.5196526499705657], 'urban': [0.46452594152228144]}

# %% [markdown]
# ## Predict % of poorest people in dataset

# %%
def pooled_features_perc(complete):   
    features = ["CNN", "OSM", "CNN+OSM"]
    feature_r2 = {}
    for feature in features:    
        r2s = []
        for i in tqdm(np.linspace(0.1,1,91)):
            perc_df = complete.loc[complete.cons_pc <= complete.cons_pc.quantile(i)]
            countries = ["NG", "ETH" ,"TZA", "MW"]
            X = None
            y = None
            for i, country in enumerate(countries):
                tmp_df = perc_df.loc[perc_df.country == country]
                years = tmp_df.groupby(["year"]).groups.keys()
                year = max(years)
                year_df = tmp_df.loc[tmp_df.year == year]
                if feature == "CNN":
                    tmp_X = np.array([np.array(x) for x in year_df["features"].values])
                elif feature == "OSM":
                    tmp_X = year_df[all_cols].values
                else:
                    cnn_X = np.array([np.array(x) for x in year_df["features"].values])
                    osm_X = year_df[all_cols].values
                    tmp_X = np.hstack((cnn_X, osm_X))
                    
                y_ = year_df["cons_pc"].values

                if X is None:
                    X = tmp_X
                else:
                    X = np.vstack((X, tmp_X))
                
                if y is None:
                    y = y_
                else:
                    y = np.append(y, y_)

            y = np.log(y)
            scaler = StandardScaler().fit(X)
            X = scaler.transform(X)
            r, _, _ = eu.run_ridge(X, y, alpha=1000)
            r2s.append(r)
        feature_r2[feature] = r2s
    
    colors = ["#2a9d8f", "#e9c46a", "#e76f51"]
    for i, feature in enumerate(feature_r2):
        plt.plot(np.linspace(0.1,1,91)*100, feature_r2[feature], c=colors[i], label=feature)
    
    plt.xlabel("Poorest percent of cluster used")
    plt.ylabel(r"$r^2$")
    plt.legend()
    ax = plt.gca()
    ax.text(-0.1, 1.1, string.ascii_uppercase[1], size=20, weight='bold', transform=ax.transAxes)
    plt.savefig("../figs/pooled_percentile.pdf", dpi=600, bbox_inches="tight")
    plt.show()

# %%
pooled_features_perc(complete_df)
# Out:
# 100%|██████████| 91/91 [00:51<00:00,  1.75it/s]
# 100%|██████████| 91/91 [00:10<00:00,  8.36it/s]
# 100%|██████████| 91/91 [00:56<00:00,  1.61it/s]

# %% [markdown]
# ## Predicting performance from each feature alone and combined

# %%
def prediction_features_performance(complete):   
    features = ["CNN", "OSM", "CNN+OSM"]
    feature_r2 = {}
    for feature in features:    
        r2s = []        
        countries = ["NG", "ETH" ,"TZA", "MW"]
        X = None
        y = None
        for i, country in enumerate(countries):
            tmp_df = complete.loc[complete.country == country]
            years = tmp_df.groupby(["year"]).groups.keys()
            year = max(years)
            year_df = tmp_df.loc[tmp_df.year == year]
            if feature == "CNN":
                tmp_X = np.array([np.array(x) for x in year_df["features"].values])
                tmp_X = StandardScaler().fit_transform(tmp_X)
            elif feature == "OSM":
                tmp_X = year_df[all_cols].values
            else:
                cnn_X = np.array([np.array(x) for x in year_df["features"].values])
                osm_X = year_df[all_cols].values
                tmp_X = np.hstack((cnn_X, osm_X))
                
            y = year_df["cons_pc"].values

            X = tmp_X
           
            y = np.log(y)
            scaler = StandardScaler().fit(X)
            X = scaler.transform(X)
            r, _, _ = eu.run_ridge(X, y, alpha=1000)
            r2s.append(r)
            feature_r2[feature] = r2s
            
    feat_df = pd.DataFrame.from_dict(feature_r2)
    feat_df["country"] = countries
    return feat_df

# %%
prediction_features_performance(complete_df)
# Out:
#         CNN       OSM   CNN+OSM country
# 0  0.468473  0.325412  0.484277      NG
# 1  0.263852  0.246082  0.266461     ETH
# 2  0.498458  0.406537  0.538819     TZA
# 3  0.441081  0.473509  0.533084      MW
